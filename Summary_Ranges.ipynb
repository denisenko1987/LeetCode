# %%
nums = [0,2,3,4,6,8,9]

# %%
list_big = []

# %%
list_big = []
start = nums[0]
for i, k in enumerate(nums[:-1]):
    # print(i,'-',k)
    if len(nums) == 0:
        return []
    if len(nums) == 1:
        return [f'{nums[0]}']
    start = nums[i]
    for i in nums[1:]
        if
# Out:
# 0 - 9
# 1 - 8
# 2 - 6
# 3 - 4
# 4 - 3
# 5 - 2
# 6 - 0

# %%
s = []
pre = start = nums[0]
print(pre)
print(start)

for i in nums[1:]:
    if i - pre != 1:
        s.append(f'{start}->{pre}' if pre - start > 0 else f'{pre}')
        start = i
    pre = i
s.append(f'{start}->{pre}' if pre - start > 0 else f'{pre}')
print(s)
# Out:
# ['0', '2->4', '6', '8->9']

# %%
n=19

# %%
[int(x) for x in list(str(n))]
# Out:
# [1, 9]

# %%
sum(x**2 for x in [int(x) for x in list(str(n))])
# Out:
# 82

# %%
s = n

while s != 1:
    list_of_dig = [int(x) for x in list(str(n))]
    s = sum(x**2 for x in list_of_dig)
    print(s)
# Out:
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# ...
